# %% [markdown]
# Licensed under the Apache License, Version 2.0.

# %%
from experimental.attentive_uncertainty.contextual_bandits.benchmark import run_trial  # local file import

# %%
num_trials = 50
deltas = [0.5, 0.7, 0.9, 0.95, 0.99]
algo_names = ['uniform']

# %%
for delta in deltas:
  print('delta', delta)
  for trial_idx in range(num_trials):
    print('trial_idx', trial_idx)
    run_trial(trial_idx=trial_idx, delta=delta, algo_names=algo_names)
# Out:
# delta 0.5
# trial_idx 0
# started
# trial_idx 1
# started
# trial_idx 2
# started
# trial_idx 3
# started
# trial_idx 4
# started
# trial_idx 5
# started
# trial_idx 6
# started
# trial_idx 7
# started
# trial_idx 8
# started
# trial_idx 9
# started
# trial_idx 10
# started
# trial_idx 11
# started
# trial_idx 12
# started
# trial_idx 13
# started
# trial_idx 14
# started
# trial_idx 15
# started
# trial_idx 16
# started
# trial_idx 17
# started
# trial_idx 18
# started
# trial_idx 19
# started
# trial_idx 20
# started
# trial_idx 21
# started
# trial_idx 22
# started
# trial_idx 23
# started
# trial_idx 24
# started
# trial_idx 25
# started
# trial_idx 26
# started
# trial_idx 27
# started
# trial_idx 28
# started
# trial_idx 29
# started
# trial_idx 30
# started
# trial_idx 31
# started
# trial_idx 32
# started
# trial_idx 33
# started
# trial_idx 34
# started
# trial_idx 35
# started
# trial_idx 36
# started
# trial_idx 37
# started
# trial_idx 38
# started
# trial_idx 39
# ...
