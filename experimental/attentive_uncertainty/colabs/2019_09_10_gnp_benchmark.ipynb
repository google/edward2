# %% [markdown]
# Licensed under the Apache License, Version 2.0.

# %%
from experimental.attentive_uncertainty.contextual_bandits import run_offline_contextual_bandits_gnp  # local file import

# %%
run_offline_contextual_bandits_gnp.benchmark()
# Out:
# Initializing model gnp_anp_beta_5.0_temp_0.001.
# Number of contexts= 100
# Number of contexts= 200
# Number of contexts= 300
# Number of contexts= 400
# Number of contexts= 500
# Number of contexts= 600
# Number of contexts= 700
# Number of contexts= 800
# Number of contexts= 900
# Number of contexts= 1000
# Number of contexts= 1100
# Number of contexts= 1200
# Number of contexts= 1300
# Number of contexts= 1400
# Number of contexts= 1500
# Number of contexts= 1600
# Number of contexts= 1700
# Number of contexts= 1800
# Number of contexts= 1900
# Number of contexts= 2000
# ---------------------------------------------------
# ---------------------------------------------------
# 0.5_0 bandit completed after 102.81050634384155 seconds.
# ---------------------------------------------------
#   0)gnp_anp_beta_5.0_temp_0.001|		 cummulative regret = 2942.751286028338.
#   1)uniform             |		 cummulative regret = 57789.40294765927.
# ...

# %%
run_offline_contextual_bandits_gnp.benchmark()
# Out:
# Initializing model gnp_acns.
# Number of contexts= 100
# Number of contexts= 200
# Number of contexts= 300
# Number of contexts= 400
# Number of contexts= 500
# Number of contexts= 600
# Number of contexts= 700
# Number of contexts= 800
# Number of contexts= 900
# Number of contexts= 1000
# Number of contexts= 1100
# Number of contexts= 1200
# Number of contexts= 1300
# Number of contexts= 1400
# Number of contexts= 1500
# Number of contexts= 1600
# Number of contexts= 1700
# Number of contexts= 1800
# Number of contexts= 1900
# Number of contexts= 2000
# ---------------------------------------------------
# ---------------------------------------------------
# 0.5_0 bandit completed after 95.6741089821 seconds.
# ---------------------------------------------------
#   0)gnp_acns            |		 cummulative regret = 1963.02329981.
#   1)uniform             |		 cummulative regret = 59361.4195529.
# ---------------------------------------------------
# ...

# %%
from experimental.attentive_uncertainty.contextual_bandits import benchmark_gnp  # local file import

# %%
benchmark_gnp.run_trial(0, 0.5, ['gnp_cnp_offline'])
# Out:
# Initializing model gnp_cnp_offline.
# started
# ['gnp_cnp_offline']
# Number of contexts= 100
# Number of contexts= 200
# Number of contexts= 300
# Number of contexts= 400
# Number of contexts= 500
# Number of contexts= 600
# Number of contexts= 700
# Number of contexts= 800
# Number of contexts= 900
# Number of contexts= 1000
# Number of contexts= 1100
# Number of contexts= 1200
# Number of contexts= 1300
# Number of contexts= 1400
# Number of contexts= 1500
# Number of contexts= 1600
# Number of contexts= 1700
# Number of contexts= 1800
# Number of contexts= 1900
# Number of contexts= 2000
# Number of contexts= 2100
# Number of contexts= 2200
# Number of contexts= 2300
# Number of contexts= 2400
# Number of contexts= 2500
# Number of contexts= 2600
# Number of contexts= 2700
# Number of contexts= 2800
# Number of contexts= 2900
# Number of contexts= 3000
# Number of contexts= 3100
# Number of contexts= 3200
# Number of contexts= 3300
# Number of contexts= 3400
# ...
